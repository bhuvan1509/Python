# %%
#project 1 :   Desigining billing system in python
print("---------Bhuvans Restarunt---------")
print("______BILL______")
print("address: Hitech city")
print("""date: 17/4/24
time:6:20pm
bill no: 150""")



print("""
MENU :
1 - chicken birryani,
2 - mutton birryani,
3 - panner birryani,
4 - veg birryani,
5 - fish birryani,
6 - prawns birryani,
7 -  Water & Cooldrinks
""")

#using python dictonary
order = {    
    1 : "chicken birryani",
    2 : "mutton birryani",
    3 : "panner birryani",
    4 : "veg birryani",
    5 : "fish birryani",
    6 : "prawns birryani",
    7 :  "Water & Cooldrinks" 
    
}
def call_end():
    print("Thankyou for visiting ...waiting for your next visit :) ")
def call_bill(bill):
    print(f"Total bill amount :{bill}")
    #SGST
    #CGST
    SGST = (bill * 2.5)/100
    CGST = (bill * 3.5 )/100
    festive_offer = (bill * 10)/100
    total_pay = bill + CGST + SGST
    print(f"SGST = {SGST}")
    print(f"CGST = {CGST}")
    print("---------------------------------------------")
    print(f"total amount to be paid = {total_pay}")
    print("---------------------------------------------")
    call_end()
    

fp  = 150 #fixed price
dp = 30 #drink price
bill = 0
def take_order(bill):
    ch = int(input("please enter your choice here:"))
    

    while ch > 0 and ch <8:
        
        if ch == 1 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
           
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            break

        elif ch == 2 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            
            break
        elif ch == 3 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            break
        elif ch == 4 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            break
        elif ch == 5 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            break
        elif ch == 6 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            break
        elif ch == 7 :
            q = int(input("enter quantity :"))
            price = q * fp
            dprice = q * dp
            print(f"order :{order[ch]} and price :{price} and quantity : {q}plates")
            bill =  bill + price
            
            take_order(bill)
            break


    
    else:
        print("bye")
        call_bill(bill)
        pass
    
    
take_order(bill)
# Out:
# ---------Bhuvans Restarunt---------
# ______BILL______
# address: Hitech city
# date: 17/4/24
# time:6:20pm
# bill no: 150
#
# MENU :
# 1 - chicken birryani,
# 2 - mutton birryani,
# 3 - panner birryani,
# 4 - veg birryani,
# 5 - fish birryani,
# 6 - prawns birryani,
# 7 -  Water & Cooldrinks
#
# please enter your choice here:1
# enter quantity :1
# order :chicken birryani and price :150 and quantity : 1plates
# please enter your choice here:1
# enter quantity :1
# order :chicken birryani and price :150 and quantity : 1plates
# please enter your choice here:9
# bye
# Total bill amount :300
# SGST = 7.5
# CGST = 10.5
# ---------------------------------------------
# total amount to be paid = 318.0
# ---------------------------------------------
# Thankyou for visiting ...waiting for your next visit :)
